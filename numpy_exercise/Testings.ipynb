# %%
print(1)
print(2)
# Out:
# 1
# 2

# %%
print("HELLO")
# Out:
# HELLO

# %%
import pandas

# %%
df=pandas.read_csv(r"C:\Users\GINNI\Downloads\abc.csv")
df
# Out:
#                            hlpi_name      series_ref quarter   hlpi   nzhec  \
# 0                     All households     HPIQ.SALL01  2008Q2  allhh       1
# 1                        Beneficiary     HPIQ.SBEN01  2008Q2  benef       1
# 2            Income quintile 1 (low)     HPIQ.SIQ101  2008Q2  disq1       1
# 3                  Income quintile 2     HPIQ.SIQ201  2008Q2  disq2       1
# 4                  Income quintile 3     HPIQ.SIQ301  2008Q2  disq3       1
# ...                              ...             ...     ...    ...     ...
# 39279         Expenditure quintile 3  HPIQ.SEQ304403  2019Q3  expq3  4.4.03
# 39280         Expenditure quintile 4  HPIQ.SEQ404403  2019Q3  expq4  4.4.03
# 39281  Expenditure quintile 5 (high)  HPIQ.SEQ504403  2019Q3  expq5  4.4.03
# 39282                          Maori  HPIQ.SMAO04403  2019Q3  maori  4.4.03
# 39283                 Superannuitant  HPIQ.SSUP04403  2019Q3  super  4.4.03
#
# ...

# %%
df7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-095ff158a76c> in <module>
# ----> 1 df7
#
# NameError: name 'df7' is not defined
