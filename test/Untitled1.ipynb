# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'abc.csv',
#  'data.csv',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testings.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
import pandas
df5= pandas.read_csv("data.csv")
df5
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6= pandas.read_csv("data.csv",header=None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns=["Id","Address","City","Zip","Country","Name","Employee"]
df6
# Out:
#    Id          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employee
# 0         8
# 1        15
# 2        25
# 3        10
# 4        12
# 5        20

# %%
df7= df6.set_index("Id")
df7
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employee
# Id
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df8=df7.set_index("Name", inplace=True, drop=False)
df8

# %%
df9 = df7.iloc[1:3,1:3 ]
df9
# Out:
#                       City               Zip
# Name
# Bready Shop  San Francisco          CA 94119
# Super River  San Francisco  California 94114

# %%
df10=df7.drop(df7.index[1:3],0)
df7
# Out:
#                      Address           City               Zip Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employee
# Name
# Madeira          Madeira         8
# Bready Shop  Bready Shop        15
# Super River  Super River        25
# Ben's Shop    Ben's Shop        10
# Sanchez          Sanchez        12
# Richvalley    Richvalley        20

# %% [markdown]
# df9 = df7.iloc[1:3,1:3 ]
# df9

# %%
df7.shape
# Out:
# (6, 6)

# %%
 df7.shape[0]
# Out:
# 6

# %%
df7["Continents"]=df7.shape[0]*["ASIA"]
df7
# Out:
#                      Address           City               Zip Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employee Continents
# Name
# Madeira          Madeira         8       ASIA
# Bready Shop  Bready Shop        15       ASIA
# Super River  Super River        25       ASIA
# Ben's Shop    Ben's Shop        10       ASIA
# Sanchez          Sanchez        12       ASIA
# Richvalley    Richvalley        20       ASIA

# %%
df7["continents"]=df7["Country"]+ "," + "ASIA"
df7
# Out:
#                      Address           City               Zip Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employee Continents continents
# Name
# Madeira          Madeira         8       ASIA   USA,ASIA
# Bready Shop  Bready Shop        15       ASIA   USA,ASIA
# Super River  Super River        25       ASIA   USA,ASIA
# Ben's Shop    Ben's Shop        10       ASIA   USA,ASIA
# Sanchez          Sanchez        12       ASIA   USA,ASIA
# Richvalley    Richvalley        20       ASIA   USA,ASIA

# %%
df7
# Out:
#                      Address           City               Zip Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employee Continents continents
# Name
# Madeira          Madeira         8       ASIA   USA,ASIA
# Bready Shop  Bready Shop        15       ASIA   USA,ASIA
# Super River  Super River        25       ASIA   USA,ASIA
# Ben's Shop    Ben's Shop        10       ASIA   USA,ASIA
# Sanchez          Sanchez        12       ASIA   USA,ASIA
# Richvalley    Richvalley        20       ASIA   USA,ASIA

# %%
df7["City"]="A"
df7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac1a287e2a1d> in <module>
# ----> 1 df7["City"]="A"
#       2 df7
#
# NameError: name 'df7' is not defined

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# c:\users\ginni\appdata\local\programs\python\python37-32\lib\site-packages\cv2\__init__.py in <module>
#       1 import importlib
#       2
# ----> 3 from .cv2 import *
#       4 from .data import *
#       5
#
# ImportError: DLL load failed: The specified module could not be found.
